# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio <h1>

# %% [markdown]
# <b>Vera Liu </b> <br>
# Data Scientist

# %% [markdown]
# <i>I am interested in data science because I enjoy drawing insight from massive data to build actionable solution </i>

# %% [markdown]
# <h3> the code in cell 5 is doing a simple mathematic calculation<h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <blockquote>This is a blocked quote</blockquote>
# <hr style="border:2px solid gray">
# <table ><tr><th >column 1 <th><th> column 2 <th><th> column 3 <tr><tr>
# <tr><td> 1 <td><td> Gaussian <td><td> .843 <td><tr><table>
